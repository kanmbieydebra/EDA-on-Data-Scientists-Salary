# %% [markdown]
# # EDA ON DATA SCIENCE JOB SALARIES

# %% [markdown]
# ## PROBLEM DEFINITION
#
# An Exploratory Data Analysis was carried out on Data Scientists salaries.
#
# - Visualisation relationships between the labels and some key features.
# - Explore correlations.
# - Univariate, bivariate, and multivariate analysis was done to visualise various correlarions as much as is feasible

# %% [markdown]
# ### Data Science Job Salaries Dataset
#
# Data science jobs are some of the fastest-growing, most in-demand in technology. Since 2012, Data Scientist roles have increased by 650 percent, and this rise shows no sign of stopping. The U.S. Bureau of Labor Statistics predicts that the demand for data science skills will increase another 27.9 percent by 2026. And, according to a report from McKinsey, that spells a shortage of between 140,000 and 190,000 people with analytical skills in the U.S. alone—not to mention another 1.5 million managers and analysts who will be required to understand how data analysis drives decision-making.
#
# Data Scientist salaries have also risen with demand; Data Scientists can typically expect to make six figures. Demand also translates into an ability to relocate far more easily—from city to city, and even internationally.

# %% [markdown]
# ### Feature Description
#
# Data Science Salaries dataset.
# Its column references are:
# - work_year: The year the salary was paid.
# - experience_level: The experience level in the job during the year with the following possible values: EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director
# - employment_type: The type of employement for the role: PT Part-time FT Full-time CT Contract FL Freelance
# - job_title: The role worked in during the year.
# - salary: The total gross salary amount paid.
# - salary_currency: The currency of the salary paid as an ISO 4217 currency code
# - salaryinusd: The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com).
# - employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code.
# - remote_ratio: The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
# - company_location: The country of the employer's main office or contracting branch as an ISO 3166 country code.
# - company_size: The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)

# %%
# import necessary libraries (analysis and visualisation)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset

salary_ds = pd.read_csv('ds_salaries.csv')
salary_ds
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
salary_ds = salary_ds.drop(["Unnamed: 0"], axis=1)

# %%
#the size of the dataset

salary_ds.shape
# Out:
# (607, 11)

# %%
#print top 5 rows with the head() method

salary_ds.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
#the tail of the data

salary_ds.tail()
# Out:
#      work_year experience_level employment_type      job_title  salary  \
# 602       2022               SE              FT  Data Engineer  154000
# 603       2022               SE              FT  Data Engineer  126000
# 604       2022               SE              FT   Data Analyst  129000
# 605       2022               SE              FT   Data Analyst  150000
# 606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# ...

# %%
#the info of the data

salary_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
#statistical information of the data

salary_ds.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count   607.000000  6.070000e+02     607.000000     607.00000
# mean   2021.405272  3.240001e+05  112297.869852      70.92257
# std       0.692133  1.544357e+06   70957.259411      40.70913
# min    2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000
# max    2022.000000  3.040000e+07  600000.000000     100.00000

# %%
#checking the missing data

salary_ds.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#checking the correlations

salary_ds.corr()
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.087577       0.170493      0.076314
# salary         -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd   0.170493 -0.083906       1.000000      0.132122
# remote_ratio    0.076314 -0.014608       0.132122      1.000000

# %%
#visualize correlation using a seaborn heatmap

plt.figure(figsize=(10,5))

sns.heatmap(salary_ds.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#visualize correlation a using seaborn pairplot

sns.pairplot(salary_ds.sample(500))
plt.show()

# %% [markdown]
# #### 1. UNIVARIATE ANALYSIS

# %% [markdown]
# #### 1.1 Categorical Columns

# %% [markdown]
# ##### 1.1.1. Experience Level

# %%
#Experience Level
#EN - Entry Level/Junior; MI - Mid Level/Intermediate; SE - Senior Level/Expert; EX - Executive Level/Director

e_l = salary_ds.groupby('experience_level').salary_in_usd.count().sort_values(ascending=True)
e_l
# Out:
# experience_level
# EX     26
# EN     88
# MI    213
# SE    280
# Name: salary_in_usd, dtype: int64

# %%
#using bar chart to visualize the experience level
#EN - Entry Level/Junior; MI - Mid Level/Intermediate; SE - Senior Level/Expert; EX - Executive Level/Director

sns.set_theme(font_scale=2)
salary_ds.experience_level.value_counts().plot.bar()
plt.title('Experience Level by Count',
             loc ='center', )
plt.xlabel('Experience Level')
# Out:
# Text(0.5, 0, 'Experience Level')

# %%
#using pie chart to visualize the experience level

sns.set_theme(font_scale=1.2)

plt.figure(figsize=(5,5))
plt.pie(e_l,labels=e_l.index, autopct="%.1f%%")

plt.title('Company Size by Percentage',
             loc ='center', )
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ##### 1.1.2. Job Titles

# %%
#Job Titles

j_t = salary_ds.groupby('job_title').work_year.count().sort_values(ascending=False)
j_t
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# ML Engineer                                   6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# ...

# %%
#use horizontal bar chart to visualize top 10 job titles

sns.set_theme(font_scale=1.5)
plt.title('Top 10 Job Titles',
             loc ='center')
plt.rcParams["figure.figsize"] = (15,10)

salary_ds["job_title"].value_counts().head(10).plot.barh("job_title")
plt.ylabel("Job Titles")

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ##### 1.1.3. Employment Type

# %%
#Employment Type
#FT - Full Time, PT - Part Time, CT - Contract, FL - Free Lance

salary_ds.groupby('employment_type').work_year.count().sort_values(ascending=False)
# Out:
# employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: work_year, dtype: int64

# %%
#distribution value of Employment Type
#FT - Full Time, PT - Part Time, CT - Contract, FL - Free Lance

salary_ds["employment_type"].value_counts(normalize=True)
# Out:
# FT    0.968699
# PT    0.016474
# CT    0.008237
# FL    0.006590
# Name: employment_type, dtype: float64

# %%
#use horizontal bar chart to visualize employment type
#FT - Full Time, PT - Part Time, CT - Contract, FL - Free Lance

salary_ds.employment_type.value_counts().plot.bar()
plt.title('Employment Type By Count',
             loc ='center', )
plt.xlabel("Employment Type")
# Out:
# Text(0.5, 0, 'Employment Type')

# %% [markdown]
# ##

# %% [markdown]
# ##### 1.1.4a. Employee Residence

# %%
#Employee Residence

salary_ds.groupby('employee_residence').company_location.count().sort_values(ascending=False)
# Out:
# employee_residence
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PK      6
# BR      6
# PT      6
# NL      5
# IT      4
# PL      4
# RU      4
# TR      3
# AE      3
# VN      3
# AT      3
# AU      3
# BE      2
# SI      2
# MX      2
# RO      2
# SG      2
# NG      2
# HU      2
# DK      2
# TN      1
# CL      1
# RS      1
# UA      1
# BG      1
# PR      1
# BO      1
# CH      1
# PH      1
# NZ      1
# EE      1
# MY      1
# DZ      1
# MT      1
# MD      1
# LU      1
# KE      1
# CN      1
# JE      1
# CO      1
# IR      1
# AR      1
# CZ      1
# IE      1
# HR      1
# HN      1
# HK      1
# IQ      1
# Name: company_location, dtype: int64

# %%
#use horizontal bar chart to visualize top 10 Employee country of Residence

sns.set_theme(font_scale=1.5)
plt.title('Top 10 Employee Residence',
             loc ='center', )
salary_ds['employee_residence'].value_counts().head(10).plot.barh('employee_residence')
plt.rcParams["figure.figsize"] = (10,8)
plt.ylabel("Employee Country of Residence")

plt.show()

# %% [markdown]
# ##### 1.1.4b. Company Location

# %%
#Company Location

salary_ds.groupby('company_location').work_year.count().sort_values(ascending=False)
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# PL      4
# PT      4
# NL      4
# AT      4
# MX      3
# LU      3
# TR      3
# PK      3
# AE      3
# AU      3
# BR      3
# DK      3
# CN      2
# CZ      2
# BE      2
# SI      2
# RU      2
# NG      2
# IT      2
# CH      2
# NZ      1
# CL      1
# EE      1
# SG      1
# UA      1
# RO      1
# CO      1
# MY      1
# DZ      1
# MT      1
# MD      1
# KE      1
# IR      1
# IQ      1
# AS      1
# IL      1
# IE      1
# HU      1
# HR      1
# HN      1
# VN      1
# Name: work_year, dtype: int64

# %%
#use horizontal bar chart to visualize top company locations

plt.title('Top 10 Company Locations',
             loc ='center', )
sns.set_theme(font_scale=1.5)
salary_ds['company_location'].value_counts().head(10).plot.barh('company_location')
plt.rcParams["figure.figsize"] = (15,10)
plt.ylabel("Company Locations")

plt.show()

# %% [markdown]
# ##### 1.1.5. Company Size

# %%
#Company Size
#S - Small, M - Medium, L - Large

c_s = salary_ds.groupby('company_size').work_year.count()
c_s
# Out:
# company_size
# L    198
# M    326
# S     83
# Name: work_year, dtype: int64

# %%
#using bar chart to visualize the company size by frequency
#S - Small, M - Medium, L - Large

sns.set_theme(font_scale=1.5)
salary_ds.company_size.value_counts().plot.bar()
plt.title('Company Size By Count',
             loc ='center', )
plt.rcParams["figure.figsize"] = (5,5)
plt.xlabel("Company Size")
# Out:
# Text(0.5, 0, 'Company Size')

# %%
#using bar chart to visualize the company size by percentage
#S - Small, M - Medium, L - Large

sns.set_theme(font_scale=1.5)
plt.figure(figsize=(5,5))
plt.pie(c_s,labels= c_s.index, autopct="%.1f%%")

plt.title('Company Size',
             loc ='center', )
plt.show()

# %% [markdown]
# #### 1.2. Numeric Columns

# %% [markdown]
# ##### 1.2.1. Work Year

# %%
#Work Year i.e. the year the salary was paid

w_y = salary_ds.groupby('work_year').work_year.count().sort_values(ascending=True)
w_y
# Out:
# work_year
# 2020     72
# 2021    217
# 2022    318
# Name: work_year, dtype: int64

# %%
#using pie chart to visualize the working year

sns.set_theme(font_scale=1.5)

plt.figure(figsize=(5,5))
plt.pie(w_y,labels= w_y.index, autopct="%.1f%%")

plt.title('Work Year in Percentage',
             loc ='center', )
plt.show()

# %% [markdown]
# ##### 1.2.2. Salary in USD

# %%
#Top salaries in USD
salary_ds.groupby('salary_in_usd').job_title.count().sort_values(ascending=False)
# Out:
# salary_in_usd
# 100000    15
# 150000    12
# 120000    12
# 200000    10
# 135000     9
#           ..
# 68428      1
# 68147      1
# 67000      1
# 66265      1
# 600000     1
# Name: job_title, Length: 369, dtype: int64

# %%
#use horizontal bar chart to visualize top earners

salary_ds['salary_in_usd'].value_counts().head(5).plot.bar('salary_in_usd')
plt.title('Top Earners in USD',
             loc ='center', )
plt.rcParams["figure.figsize"] = (15,10)
plt.xlabel("Frequency")
plt.ylabel("Salary in USD")


plt.show()

# %% [markdown]
# ##### 1.2.3. Remote Ratio

# %%
#Remote Ratio
#The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%), 50 Partially remote (20% to 80%), 100 Fully remote (more than 80%)

rr = salary_ds.groupby('remote_ratio').work_year.count().sort_values(ascending=True)
rr
# Out:
# remote_ratio
# 50      99
# 0      127
# 100    381
# Name: work_year, dtype: int64

# %%
#using pie chart to visualize remote ratio

sns.set_theme(font_scale=1.5)

plt.figure(figsize=(5,5))
plt.pie(rr,labels= rr.index, autopct="%.1f%%")

plt.title('Remote Ratio',
             loc ='center', )
plt.show()

# %% [markdown]
# ### 2. Work Year Analysis

# %% [markdown]
# ##### 2.1. Remote Ratio by Work Year

# %%
#Remote work by work year

sns.set_theme(font_scale=1.5)
plt.figure(figsize=(10,5))
plt.title('Top 3 Job Title by Experience Level')
sns.barplot(x='work_year', y='remote_ratio', data=salary_ds)
plt.xlabel("Work Year")
plt.ylabel("Remote Ratio")
# Out:
# Text(0, 0.5, 'Remote Ratio')

# %%
#Remote ratio salary range by work year

plt.title('Remote Ratio Salary range by work year',
             loc ='center', )
sns.barplot(
    x='work_year', 
    y='salary_in_usd', 
    data=salary_ds, 
    hue='remote_ratio')
plt.xlabel("Work Year")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ### 3. Experience Level Analysis

# %% [markdown]
# ##### 3.1. Employment Type by Experience Level

# %%
#Experience Level
#EN - Entry Level/Junior; MI - Mid Level/Intermediate; SE - Senior Level/Expert; EX - Executive Level/Director

sns.barplot(
    x='experience_level', 
    y='salary_in_usd', 
    data=salary_ds, 
    hue='employment_type')
plt.title('Employment Type Salary Range by Experience level',
             loc ='center', )
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 3.2. Top 3 Job Title by Experience Level

# %%
#Top 3 Job Title
#EN - Entry Level/Junior; MI - Mid Level/Intermediate; SE - Senior Level/Expert; EX - Executive Level/Director

sns.set_theme(font_scale=2)
plt.title('Top 3 Job Title by Experience Level')
sns.barplot(
    hue='experience_level', 
    y='salary_in_usd', 
    data=salary, 
    x= salary_ds.job_title[:3])
plt.xlabel("Job Title")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 3.3. Company Size by Experience Level

# %%
#Experience Level
#EN - Entry Level/Junior; MI - Mid Level/Intermediate; SE - Senior Level/Expert; EX - Executive Level/Director
#Company Size: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)

sns.barplot(
    x='experience_level', 
    y='salary_in_usd', 
    data=salary_ds, 
    hue='company_size')
sns.set_theme(font_scale=2)
plt.title('Company Size by Experience Level')
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ### 4. Company Location Analysis

# %% [markdown]
# ##### 4.1. Experience Level

# %%
#Top company location by experience level

sns.barplot(
    x=salary_ds.company_location[:11], 
    y='salary_in_usd', 
    data=salary_ds, 
    hue='experience_level')
sns.set_theme(font_scale=2)
plt.title('Company Location by Experience Level')
plt.xlabel("Company Location")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ### 5. Salary Analysis

# %% [markdown]
# #####  5.1. Salary by Work Year

# %%
#Salary by work year

sns.barplot(
    x='work_year', 
    y='salary_in_usd', 
    data=salary_ds)
sns.set_theme(font_scale=2)
plt.title('Salary Analysis by Work Year')
plt.xlabel("Work Year")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 5.2. Salary by Experience Level

# %%
sns.barplot(
    x='experience_level', 
    y='salary_in_usd', 
    data=salary_ds)
sns.set_theme(font_scale=2)
plt.title('Salary Analysis by Experience Level')
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 5.3. Salary by Company Size

# %%
#S - small; M - medium; L - large

sns.set_theme(font_scale=2)
sns.barplot(
    x='company_size', 
    y='salary_in_usd', 
    data=salary_ds)
plt.title('Salary Analysis by Company Size')
plt.xlabel("Company Size")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 5.4. Highest Salaries by Job Title

# %%
#Highest salaries by job titles

sns.set_theme(font_scale=1.4)
plt.figure(figsize=(20,10))
sns.barplot(
    x=salary.job_title[:7], 
    y='salary_in_usd', 
    data=salary_ds)
plt.title('Highest Salary by Job Title')
plt.xlabel("Job Title")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %% [markdown]
# ##### 5.5. Average Salary by Company Location

# %%
#Top average salary by company location

sns.barplot(
    x=salary_ds.company_location[:5], 
    y='salary_in_usd', 
    data=salary_ds,)
sns.set_theme(font_scale=2)
plt.title('Average Salary by Company Location')
plt.xlabel("Company Location")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')

# %%
#Top average salary by company location and experience level

sns.set_theme(font_scale=1)
sns.barplot(
    x=salary_ds.company_location[:5], 
    y='salary_in_usd', 
    data=salary_ds,
    hue = 'experience_level')
plt.title('Average Salary by Company Size and Experience Level')
plt.xlabel("Experience Level")
plt.ylabel("Salary in USD")
# Out:
# Text(0, 0.5, 'Salary in USD')
